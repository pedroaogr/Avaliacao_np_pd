# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/pedroaogr/Avaliacao_np_pd/main/Copas_do_Mundo.csv"

df = pd.read_csv(url, sep=';', encoding='latin-1')

df.head()
# Out:
#      Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930.0      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934.0        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938.0       France       Italy         Hungary   Brazil      Sweden
# 3  1950.0       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954.0  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    Goals Scored  Qualified Teams  Matches Played  Attendance  \
# 0          70.0             13.0            18.0    590549.0
# 1          70.0             16.0            17.0    363000.0
# 2          84.0             15.0            18.0    375700.0
# 3          88.0             13.0            22.0   1045246.0
# 4         140.0             16.0            26.0    768607.0
#
#           Top Scorer            Team  Goals  Unnamed: 13
# 0  Guillermo Stábile       Argentina    8.0          NaN
# ...

# %%
df.info()
df.columns
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             22 non-null     float64
#  1   Country          22 non-null     object
#  2   Winner           22 non-null     object
#  3   Runners-Up       22 non-null     object
#  4   Third            22 non-null     object
#  5   Fourth           22 non-null     object
#  6   Goals Scored     22 non-null     float64
#  7   Qualified Teams  22 non-null     float64
#  8   Matches Played   22 non-null     float64
#  9   Attendance       22 non-null     float64
#  10  Top Scorer       22 non-null     object
#  11  Team             22 non-null     object
#  12  Goals            22 non-null     float64
#  13  Unnamed: 13      0 non-null      float64
# dtypes: float64(7), object(7)
# memory usage: 2.6+ KB
# (23, 14)

# %%
#Quesito_1: Quem ganhou mais vezes a Copa do Mundo?
df['Winner'].value_counts()

# %%
#Quesito_2: Quais paises mais chegaram em finais?
df['Winner'].value_counts() + df['Runners-Up'].value_counts()

# %%
#Quesito_3: Mostrar as estatíticas dos gols marcados em todas as Copas do Mundo:
df['Goals Scored'].describe().round(2)

# %%
#Quesito_4: Quais paises mais sediaram a Copa
df['Country'].value_counts()
